# %% [markdown]
# Scraping Part

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from tqdm import tqdm
import datetime
import pytz

# %%
class BookScraper:
    def __init__(self):
        self.collections = [] # List to store collection URLs
        self.all_books_url = [] # List to store URLs of all books
        self.all_books_data = [] # List to store data of all books
        self.df = None # DataFrame to store book data

    def scrape_collections(self, url):
        # Scrape collection URLs from the main page
        r = requests.get(url)
        soup = BeautifulSoup(r.text, 'html.parser')

        for i in soup.find_all(href=True):
            if i['href'].startswith('/collection/knigi-') or i['href'].startswith('/collection/books'):
                self.collections.append('https://alinino.az/' + i['href'])

    def scrape_collection_books(self, collection_url):
        # Scrape book URLs from a collection page
        r = requests.get(collection_url)
        soup = BeautifulSoup(r.text, 'html.parser')

        category_div = soup.find_all('div', {'class': 'product-card-image'})

        for i in category_div:
            self.all_books_url.append(('https://alinino.az' + i.find(href=True)['href']).strip())

    def scrape_book(self, news_url):
        #Scrape data of an individual book
        result_dict = {}
        r = requests.get(news_url)
        soup = BeautifulSoup(r.text, 'html.parser')

        product_title = soup.find('h1', attrs={'itemprop': 'name'}).text

        product_price = soup.find('div', attrs={'class': 'price js-product-price on-page'}).text
        product_price = product_price.split('\xa0')[0] + ' ' + product_price.split('\xa0')[1]

        try:
            author = ((soup.find_all('div', attrs={'class': 'properties_item'})[1]).get_text(strip=True)).split("Müəllif:")[1]
        except:
            author = '----'

        try:
            publishing = ((soup.find_all('div', attrs={'class': 'properties_item'})[0]).get_text(strip=True)).split(":")[1]
        except:
            publishing = '----'

        result_dict = {"Kitabın adı": product_title,
                       "Müəllif": author,
                       "Nəşriyyat": publishing,
                       "Qiymət": product_price}
        return result_dict

    def scrape_all_books(self):
        # Scrape data of all books from the collection URLs
        for i in self.collections:
            self.scrape_collection_books(i)

        for i in tqdm(self.all_books_url):
            try:
                self.all_books_data.append(self.scrape_book(i))
            except:
                pass

    def generate_dataframe(self):
        # Generate a DataFrame from the scraped book data
        self.df = pd.DataFrame(self.all_books_data)
        self.df["Stok"] = np.random.randint(0, 18, size=len(self.df))
        self.df["ID"] = np.random.choice(range(100000, 150000), size=len(self.df), replace=False)
        self.df.set_index('ID', inplace=True)

# %%
scraper = BookScraper()

# %%
scraper.scrape_collections('https://alinino.az/#')
scraper.scrape_all_books()
scraper.generate_dataframe()
df_all_books = scraper.df
# Out:
# 100%|██████████| 210/210 [05:05<00:00,  1.45s/it]

# %%
df_all_books.to_csv('list_of_books.csv')

# %%
df_all_books
# Out:
#                                               Kitabın adı  \
# ID
# 108319     Evdə və məktəbdə addım-addım montessori təlimi
# 111414                                  Zamanın sınağında
# 145358                                       İnsan nədir?
# 122619        Açıq cəmiyyət və onun düşmənləri ( I cild )
# 130238                                                Yol
# ...                                                   ...
# 143099                                      Fanny- French
# 129601                          La fille du train- French
# 115256                                 La Nausee - French
# 124046                 LA FILLE DE LA CORNE D OR - French
# 123749  Le pouvoir du moment present: guide d'eveil sp...
#
#                     Müəllif         Nəşriyyat     Qiymət  Stok
# ID
# 108319   İrem Savcı Köroğlu  Qanun Nəşriyyatı   8.79 AZN     8
# 111414                 ----     Cəmil Həsənli   9.50 AZN     2
# 145358            Mark Tven  Qanun Nəşriyyatı   3.19 AZN    13
# 122619  Karl Raymund Popper  Qanun Nəşriyyatı  14.39 AZN    12
# 130238      Kormak Makkarti  Qanun Nəşriyyatı   9.59 AZN     5
# ...                     ...               ...        ...   ...
# 143099                 ----     Marcel Pagnol  14.48 AZN     7
# 129601                 ----     PAULA HAWKINS     24 AZN     9
# 115256                 ----  Jean-Paul Sartre  17.28 AZN    11
# 124046                 ----       Kurban Said  17.20 AZN     0
# 123749                 ----     Eckhart Tolle  12.80 AZN    11
#
# [209 rows x 5 columns]

# %% [markdown]
# Main part

# %%
class Bookstore:
    """
    A class representing a bookstore.
    This class manages the inventory and sales operations of the bookstore.
    It provides methods for adding books, generating sales reports, and
    maintaining the stock.
    """
    def __init__(self):
        """
        Initialize the Bookstore object.
        Load the bookstore inventory from a CSV file and set the index to book ID.
        Initialize an empty DataFrame for the sales report.
        Initialize empty lists and strings for book and count information.
        """
        self.bookstore_data = pd.read_csv("list_of_books.csv")
        self.bookstore_data.set_index('ID', inplace=True)
    
        self.df_sales_report = pd.DataFrame(columns=['Date', 'Book Name', 'Count', "Price", 'Total Price'])

        self.book_enough_id = []
        self.book_enough_count = []

        self.book_not_enough_id = []
        self.book_not_enough_count =[]

        self.not_found = []
        self.book_string = ''
        self.count_string = ''
        self.book_not_found = ''

    def add_book(self, id, count):
        """
        Add books to the inventory.
        Args:
        id (int): ID of the book.
        count (int): Number of books to add.
        """
        self.bookstore_data.loc[id, 'Stok'] += count
        print(f"Kitab əlavə edildi. Artıq bu kitabdan {self.bookstore_data.loc[id, 'Stok']} ədəd vardır.")

    def delete_book(self, id):
        """
        Delete a book from the inventory.
        Args:
            id (int): ID of the book.
        """
        if id not in self.bookstore_data.index:
            print("Kitab tapılmadı.")
        else:
            self.bookstore_data = self.bookstore_data.drop(id)
            print("Kitab silindi.")

    def reset_var(self):
        """
        Reset the variables used for book tracking.
        """
        self.book_enough_id = []
        self.book_enough_count = []
        self.book_not_enough_id = []
        self.book_not_enough_count =[]

        self.not_found = []
        self.book_string = ''
        self.count_string = ''
        self.book_not_found = ''

    def sell_book(self):
        """
        Sell books and generate sales report.
        """
        book_ids = list(map(int,input("ID'ləri daxil edin (boşluq ilə ayırın): ").split()))
        book_num = list(map(int,input("Sayları daxil edin (boşluq ilə ayırın): ").split()))
        self.not_found = [id for id in book_ids if id not in self.bookstore_data.index ]

        for id in range(len(book_ids)): #user's preferences
            if book_ids[id] in self.bookstore_data.index:#if they match with our products
                if self.bookstore_data.loc[book_ids[id], 'Stok']==0:
                    self.not_found+=[book_ids[id]]
                elif self.bookstore_data.loc[book_ids[id], 'Stok'] < book_num[id]:#Supply<Demand=>group them like "not enough"
                    self.book_not_enough_id += [book_ids[id]] 
                    self.book_not_enough_count += [self.bookstore_data.loc[book_ids[id], 'Stok']]
                else:
                    #Supply>=Demand=>group them like "enough"
                    self.book_enough_id += [book_ids[id]]
                    self.book_enough_count +=[book_num[id]]

        if len(self.not_found)>0:
            self.book_not_found = ' '.join(map(str, self.not_found))
            print(f"Təəssüf ki, {self.book_not_found} kitabları tapılmadı.")

        if len(self.book_not_enough_id)>0:
            self.book_string = ' '.join(map(str, self.book_not_enough_id))
            self.count_string = ' '.join(map(str, self.book_not_enough_count))
            print(f"Təəssüf ki, {self.book_string} kitablarından {self.count_string} sayda qalıb.")

            if input(f"Sayı az olan {self.book_string} id-li kitabları almaq istəyirsinizmi?") == "+":
                self.book_enough_id += self.book_not_enough_id
                self.book_enough_count += self.book_not_enough_count

        if len(self.book_enough_id)>0:
            if input("Uyğun olan kitabları almaq üçün sifarişi təsdiq etmək istəyirsinizmi?") == "+":
                self.sales_report()
                self.receipt()
        else:
            self.reset_var()
            print("Sifariş ləğv olundu!")


    def receipt(self):    
        """
        Generate a receipt for the sold books.
        """
        local_tz = pytz.timezone('Asia/Baku')
        current_date = datetime.datetime.now(local_tz)
        formatted_datetime = current_date.strftime("%Y-%m-%d %I:%M %p")

        self.bookstore_data.loc[self.book_enough_id, 'Stok'] -= self.book_enough_count

        print('-'*60)
        print('elEGant Book Store')
        print('30 Khojali Avenue, Baku, Azerbaijan')
        print('-'*60)
        print(f'Date: {formatted_datetime}')
        print('Receipt Number: 00123')
        print('-'*60)

        category2= self.book_enough_id   #will be the names of the books"
        category3= self.book_enough_count  #count of each
        category4=[float(str(self.bookstore_data.loc[i, 'Qiymət']).split('AZN')[0]) for i in self.book_enough_id ]  #price of each
        category5=[i*j for i,j in zip(category3,category4)]  #count*price of each 

        a1="Item";a2="Quantity";a3="Price";a4="Subtotal"
        print(f"{a1}{' '*5}\t{a2}{' '*10}\t{a3}{' '*10}\t{a4}") #header

        for a1, a2, a3, a4 in zip(category2,category3,category4,category5):
            print(f"{a1}{' '*10}\t{a2}{' '*10}\t{round(a3,2)}{' '*5}\t{round(a4,2)}")
        print()
        print(f"Subtotal:{' '*46}{round(sum(category5),2)}")
        print(f"Tax:     {' '*47}{round(sum(category5)*0.07,2)}")
        print('-'*60)

        print(f"Grand Total:{' '*42}{round(sum(category5)*0.93,2)}")
        print('-'*60)

        self.reset_var()


    def sales_report(self):
        """
        Generate a sales report for the sold books.
        """
        local_tz = pytz.timezone('Asia/Baku')
        current_date = datetime.datetime.now(local_tz)
        formatted_datetime = current_date.strftime("%Y-%m-%d %I:%M %p")

        book_name = self.book_enough_id  # will be the names of the books
        book_count = self.book_enough_count  # count of each
        book_price = [float(str(self.bookstore_data.loc[i, 'Qiymət']).split('AZN')[0]) for i in self.book_enough_id]  # price of each
        total_price = [i * j for i, j in zip(book_count, book_price)]  # count * price of each

        report_data = {
            "Date": [formatted_datetime] * len(self.book_enough_id),
            "Book Name": book_name,
            "Count": book_count,
            "Price": book_price,
            "Total Price": total_price}
        new_df = pd.DataFrame(report_data)

        self.df_sales_report = pd.concat([self.df_sales_report, new_df], ignore_index=True)


    def return_df(self):
        """
        Return the bookstore inventory DataFrame.
        """
        return self.bookstore_data

    def return_sales_report(self):
        """
        Generate and return the sales report DataFrame.
        """
        self.df_sales_report.to_csv("sales_report.csv", index=False)
        print("Sales report generated successfully!")
        return self.df_sales_report

    def alert_system(self):
        """
        Check for books with low stock and return the alert data.
        """
        alert_data = self.bookstore_data[self.bookstore_data['Stok']<5]
        return alert_data

# %%
bookstore=Bookstore()

# %%
bookstore.add_book(145358,15)
# Out:
# Kitab əlavə edildi. Artıq bu kitabdan 28 ədəd vardır.

# %%
bookstore.delete_book(145358)
# Out:
# Kitab silindi.

# %%
bookstore.alert_system()
# Out:
#                                               Kitabın adı  \
# ID
# 111414                                  Zamanın sınağında
# 125611                                       Qara qu quşu
# 109013                              Məsumluğumu itirərkən
# 114648                              Gənc şairin dilemması
# 103021                     Uşaqla necə ünsiyyət saxlamalı
# 130036                                      Yadlar ölkəsi
# 123759                                   Müdriklik məbədi
# 149477                                    Lokla 90 dəqiqə
# 128523                                    Konsulun köpəyi
# 110104                                     Kərim Xan Zənd
# 100740                             Gizli imzalı məqalələr
# 135557                            Ayaqqabılarını çıxar...
# 130638                                       Pişik beşiyi
# 134931                                 Daxili mühəndislik
# 132038                               Albalının cinsiyyəti
# 140812  Vaqif Mustafazadə: əfsanəsi, tarixi, həyatı, y...
# 134358                             Мани, или Азбука денег
# 119830                                       Черный город
# 142664                                    Турецкий гамбит
# 103936                Тафти жрица 2. Управление событиями
# 109461                                Французская волчица
# 134042                В поисках утраченного времени том 2
# 114863  Праведный палач:жизнь,смерть,честь и позор в X...
# 112297                               Оракул Средневековья
# 117201  Густав Климт. Шедевры графики в эксклюзивном о...
# 108149         Curious Questions Answers about Our Planet
# 130049            Curious Questions Answers about Animals
# 123400      Curious Questions & Answers About Polar Lands
# 128354       Curious Questions & Answers About Our Oceans
# 133515                   Get Set Go: Flashcards - Animals
# 137825        Get Set Go: Flashcards - Colours and Shapes
# 112036                                   First Space Book
# 107622                      Skandar and the Unicorn Thief
# 107698                                     What Dogs Want
# 146777                                  We See Everything
# 121259                              We Are Bound by Stars
# 122362                           We Are Blood And Thunder
# 102404  Leviathan - Bir Din ve Dünya Devletinin İçeriğ...
# 120051                                 Galateia: Bir Öykü
# 107010       Benim Küçük Sırrım Serisi Hediyeli Özel Kutu
# 134880                                  Yeniden Biz Olmak
# 106975                    DSM - 5e Göre Anormal Psikoloji
# 101873                                 Psikoloji ve Yaşam
# 129299                                     Kokular Kitabı
# 105834     Zamanın Daha Kısa Kısa Tarihi - Renkli Resimli
# 110081  Hepimiz Gökyüzü Olmak İstedik - Krallar ve Soy...
# 110425                                     Sobe (Cep Boy)
# 145365                                Saklambaç (Cep Boy)
# 106783            Erkundungen Deutsch Als Fremdsprache B2
# 149567    Keine Begegnung İn Unserem Leben İst Ein Zufall
# 137046  Club de la pluie et les forbans de la nuit - F...
# 145618                  Le Comte de Monte-Cristo - French
# 118430                          La chambre bleue - French
# 108960                 Le Petit Nicolas s'amuse -  French
# 143625  Les histoires inedites du Petit Nicolas, 4  - ...
# 136148   Le nouveau nom : L'amie prodigieuse II -  French
# 121587                         Un lieu incertain-  French
# 130441        Sale temps pour les pattes noires !- French
# 124046                 LA FILLE DE LA CORNE D OR - French
#
#                                        Müəllif  \
# ID
# 111414                                    ----
# 125611                    Nassim Nikolas Taleb
# 109013                          Riçard Branson
# 114648                          Cəlil Cavanşir
# 103021                            Səidə İkigai
# 130036                           Leyla Slimani
# 123759                             Əlisa Nicat
# 149477                            Pol Stretern
# 128523                            Şərəf Yılmaz
# 110104                         Məhbubə Tehrani
# 100740                      Mir Cəfər Pişəvəri
# 135557                      Etel Lilian Voyniç
# 130638                           Kurt Vonnegut
# 134931                                 Sadquru
# 132038                         Cenet Vinterson
# 140812                           Rauf Fərhadov
# 134358                              Бодо Шефер
# 119830                            Борис Акунин
# 142664                            Борис Акунин
# 103936                            Вадим Зеланд
# 109461                             Морис Дрюон
# 134042                           Марсель Пруст
# 114863                        Джоэл Харрингтон
# 112297                          Елена Дроздова
# 117201                          Мария Терешина
# 108149                  Camilla de la Bedoyere
# 130049                  Camilla de la Bedoyere
# 123400                            Sue Nicholls
# 128354                  Camilla De la Bédoyère
# 133515                           Susan Purcell
# 137825                           Susan Purcell
# 112036                           Clive Gifford
# 107622                          A. F. Steadman
# 107698                                Mat Ward
# 146777                       William Sutcliffe
# 121259                              Kesia Lupo
# 122362                              Kesia Lupo
# 102404                           Thomas Hobbes
# 120051                         Madeline Miller
# 107010                           Dilara Keskin
# 134880                             Hakan Özkan
# 106975                                    ----
# 101873  Philip G. Zimbardo , Richard J. Gerrig
# 129299                              Vedat Ozan
# 105834                         Stephen Hawking
# 110081                              N.G. Kabal
# 110425                              N.G. Kabal
# 145365                              N.G. Kabal
# 106783                                    ----
# 149567                            Hakan Mengüç
# 137046                                    ----
# 145618                                    ----
# 118430                                    ----
# 108960                                    ----
# 143625                                    ----
# 136148                                    ----
# 121587                                    ----
# 130441                                    ----
# 124046                                    ----
#
#                                          Nəşriyyat     Qiymət  Stok
# ID
# 111414                               Cəmil Həsənli   9.50 AZN     2
# 125611                            Qanun Nəşriyyatı  12.79 AZN     0
# 109013                            Qanun Nəşriyyatı  16.79 AZN     4
# 114648                            Qanun Nəşriyyatı   3.99 AZN     1
# 103021                            Qanun Nəşriyyatı      8 AZN     4
# 130036                            Qanun Nəşriyyatı  10.39 AZN     2
# 123759                            Qanun Nəşriyyatı  31.99 AZN     0
# 149477                            Qanun Nəşriyyatı   3.99 AZN     0
# 128523                            Qanun Nəşriyyatı   6.39 AZN     0
# 110104                            Qanun Nəşriyyatı   9.59 AZN     2
# 100740                            Qanun Nəşriyyatı   9.59 AZN     1
# 135557  Əli və Nino Nəşriyyatı və Qanun Nəşriyyatı   9.59 AZN     3
# 130638                            Qanun Nəşriyyatı   9.59 AZN     2
# 134931                            Qanun Nəşriyyatı  11.19 AZN     3
# 132038                            Qanun Nəşriyyatı   7.19 AZN     0
# 140812                            Qanun Nəşriyyatı   7.99 AZN     4
# 134358                                     Попурри  15.52 AZN     2
# 119830                            Издатель Захаров  17.36 AZN     2
# 142664                            Издатель Захаров     16 AZN     1
# 103936                                        Весь  31.60 AZN     3
# 109461                                      Азбука   6.32 AZN     4
# 134042                                 Альфа-книга  64.64 AZN     4
# 114863                            Альпина Паблишер  27.44 AZN     1
# 112297                                       Эксмо     30 AZN     4
# 117201                                       Эксмо  55.76 AZN     0
# 108149                                 Miles Kelly  23.44 AZN     4
# 130049                                 Miles Kelly  23.44 AZN     1
# 123400                  Miles Kelly Publishing Ltd  28.16 AZN     4
# 128354                                 Miles Kelly  23.44 AZN     3
# 133515                  Miles Kelly Publishing Ltd     14 AZN     3
# 137825                  Miles Kelly Publishing Ltd     14 AZN     3
# 112036                                 Miles Kelly  28.16 AZN     3
# 107622                         Simon & Schuster UK  16.08 AZN     3
# 107698                  Bloomsbury Publishing (UK)  26.08 AZN     2
# 146777                  Bloomsbury Publishing (UK)  20.08 AZN     3
# 121259                  Bloomsbury Publishing (UK)  18.08 AZN     1
# 122362                  Bloomsbury Publishing (UK)  18.08 AZN     3
# 102404                        Yapı Kredi Yayınları  12.88 AZN     1
# 120051                            İthaki Yayınları   6.48 AZN     3
# 107010                           Ephesus Yayınları  44.32 AZN     1
# 134880                           Olimpos Yayınları   8.40 AZN     4
# 106975                   Nobel Akademik Yayıncılık  18.24 AZN     0
# 101873                   Nobel Akademik Yayıncılık  32.24 AZN     1
# 129299                           Everest Yayınları  18.48 AZN     0
# 105834                             Alfa Yayıncılık   7.28 AZN     0
# 110081                             Martı Yayınları  22.32 AZN     4
# 110425                             Martı Yayınları   7.76 AZN     4
# 145365                             Martı Yayınları   7.76 AZN     3
# 106783                                        ----      8 AZN     2
# 149567                            Destek Yayınları   9.36 AZN     0
# 137046                            Malika Ferdjoukh  21.76 AZN     0
# 145618                             Alexandre Dumas  14.64 AZN     0
# 118430                             Georges Simenon  13.52 AZN     2
# 108960                              Sempe Goscinny  16.80 AZN     3
# 143625                              Sempe Goscinny  16.80 AZN     1
# 136148                              Elena Ferrante  21.20 AZN     4
# 121587                                 Fred Vargas  18.72 AZN     1
# 130441                             Claudine Aubrun  16.40 AZN     2
# 124046                                 Kurban Said  17.20 AZN     0

# %%
bookstore.return_df()
# Out:
#                                               Kitabın adı  \
# ID
# 108319     Evdə və məktəbdə addım-addım montessori təlimi
# 111414                                  Zamanın sınağında
# 122619        Açıq cəmiyyət və onun düşmənləri ( I cild )
# 130238                                                Yol
# 131649                                      Ronaldonu al!
# ...                                                   ...
# 143099                                      Fanny- French
# 129601                          La fille du train- French
# 115256                                 La Nausee - French
# 124046                 LA FILLE DE LA CORNE D OR - French
# 123749  Le pouvoir du moment present: guide d'eveil sp...
#
#                                  Müəllif         Nəşriyyat     Qiymət  Stok
# ID
# 108319                İrem Savcı Köroğlu  Qanun Nəşriyyatı   8.79 AZN     8
# 111414                              ----     Cəmil Həsənli   9.50 AZN     2
# 122619               Karl Raymund Popper  Qanun Nəşriyyatı  14.39 AZN    12
# 130238                   Kormak Makkarti  Qanun Nəşriyyatı   9.59 AZN     5
# 131649  Mario Leo və Aleks Fon Kuçkovski  Qanun Nəşriyyatı  11.99 AZN    16
# ...                                  ...               ...        ...   ...
# 143099                              ----     Marcel Pagnol  14.48 AZN     7
# 129601                              ----     PAULA HAWKINS     24 AZN     9
# 115256                              ----  Jean-Paul Sartre  17.28 AZN    11
# 124046                              ----       Kurban Said  17.20 AZN     0
# 123749                              ----     Eckhart Tolle  12.80 AZN    11
#
# [208 rows x 5 columns]

# %%
bookstore.sell_book()
# Out:
# ID'ləri daxil edin (boşluq ilə ayırın): 122619 143099
# Sayları daxil edin (boşluq ilə ayırın): 15 5
# Təəssüf ki, 122619 kitablarından 12 sayda qalıb.
# Sayı az olan 122619 id-li kitabları almaq istəyirsinizmi?+
# Uyğun olan kitabları almaq üçün sifarişi təsdiq etmək istəyirsinizmi?+
# ------------------------------------------------------------
# elEGant Book Store
# 30 Khojali Avenue, Baku, Azerbaijan
# ------------------------------------------------------------
# Date: 2023-05-25 12:43 PM
# Receipt Number: 00123
# ------------------------------------------------------------
# Item     	Quantity          	Price          	Subtotal
# 143099          	5          	14.48     	72.4
# 122619          	12          	14.39     	172.68
#
# Subtotal:                                              245.08
# Tax:                                                    17.16
# ------------------------------------------------------------
# Grand Total:                                          227.92
# ------------------------------------------------------------

# %%
bookstore.return_sales_report()
# Out:
# Sales report generated successfully!
#                   Date Book Name Count  Price  Total Price
# 0  2023-05-25 12:43 PM    143099     5  14.48        72.40
# 1  2023-05-25 12:43 PM    122619    12  14.39       172.68

# %%
bookstore.sell_book()
# Out:
# ID'ləri daxil edin (boşluq ilə ayırın): 111414 145358
# Sayları daxil edin (boşluq ilə ayırın): 2 4
# Təəssüf ki, 145358 kitabları tapılmadı.
# Uyğun olan kitabları almaq üçün sifarişi təsdiq etmək istəyirsinizmi?+
# ------------------------------------------------------------
# elEGant Book Store
# 30 Khojali Avenue, Baku, Azerbaijan
# ------------------------------------------------------------
# Date: 2023-05-25 12:44 PM
# Receipt Number: 00123
# ------------------------------------------------------------
# Item     	Quantity          	Price          	Subtotal
# 111414          	2          	9.5     	19.0
#
# Subtotal:                                              19.0
# Tax:                                                    1.33
# ------------------------------------------------------------
# Grand Total:                                          17.67
# ------------------------------------------------------------

# %%
bookstore.return_sales_report()
# Out:
# Sales report generated successfully!
#                   Date Book Name Count  Price  Total Price
# 0  2023-05-25 12:43 PM    143099     5  14.48        72.40
# 1  2023-05-25 12:43 PM    122619    12  14.39       172.68
# 2  2023-05-25 12:44 PM    111414     2   9.50        19.00
